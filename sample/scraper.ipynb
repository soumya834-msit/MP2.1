# %% [markdown]
# # Scraping UIUC CS faculty homepages

# %% [markdown]
# ## System setup
#
# Before we start, make sure to install the required libraries
#
#     pip install bs4
#     pip install selenium
#
# Since UIUC's website has some javascript rendered HTML content, we'll be using Selenium for scraping the content loaded dynamically by javascript. For this,you would also need to download a selenium supported browser webdriver.
#
# e.g. For Chrome, download the appropriate webdriver from here: http://chromedriver.chromium.org/downloads, unzip it and save in current directory.

# %%
from bs4 import BeautifulSoup
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
import re 
import urllib
import time

# %%
#create a webdriver object and set options for headless browsing
options = Options()
options.headless = True
driver = webdriver.Chrome('./chromedriver',options=options)

# %% [markdown]
# If you visit UIUC's CS Faculty Directory Listing: https://cs.illinois.edu/about/people/all-faculty , you'll notice that it has all the faculty listed there.
# Clicking on a faculty's name takes you to the Faculty Profile page.
# The profile page has more info about the faculty and sometimes contains the faculty hompage url under the "For More Information" header which is what we want to scrape.
#
# Before we start scraping, we'll define some helper functions

# %%
#uses webdriver object to execute javascript code and get dynamically loaded webcontent
def get_js_soup(url,driver):
    driver.get(url)
    res_html = driver.execute_script('return document.body.innerHTML')
    soup = BeautifulSoup(res_html,'html.parser') #beautiful soup object to be used for parsing html content
    return soup

#tidies extracted text 
def process_bio(bio):
    bio = bio.encode('ascii',errors='ignore').decode('utf-8')       #removes non-ascii characters
    bio = re.sub('\s+',' ',bio)       #repalces repeated whitespace characters with single space
    return bio

''' More tidying
Sometimes the text extracted HTML webpage may contain javascript code and some style elements. 
This function removes script and style tags from HTML so that extracted text does not contain them.
'''
def remove_script(soup):
    for script in soup(["script", "style"]):
        script.decompose()
    return soup


#Checks if bio_url is a valid faculty homepage
def is_valid_homepage(bio_url,dir_url):
    if bio_url.endswith('.pdf'): #we're not parsing pdfs
        return False
    try:
        #sometimes the homepage url points to the same page as the faculty profile page
        #which should be treated differently from an actual homepage
        ret_url = urllib.request.urlopen(bio_url).geturl() 
    except:
        return False       #unable to access bio_url
    urls = [re.sub('((https?://)|(www.))','',url) for url in [ret_url,dir_url]] #removes url scheme (https,http or www) 
    return not(urls[0]== urls[1])

# %% [markdown]
# We will now start scraping.
#
# First, let's get links to all Faculty Profile pages by scraping the Directory Listing. You can use your browser's developer tools to find the required links within the HTML content. In Chrome, this can be done by right cliking on the webpage and choosing Inspect. Some basic knowledge of HTML and CSS would be required. After a bit of digging, you should notice that the link can be found under the <a\> tag of <div\> with the class "name" as shown:
#
# ![img1.png](attachment:img1.png)
#
#
# Now we can specify exactly what needs to be extracted from the directory listing page

# %%
#extracts all Faculty Profile page urls from the Directory Listing Page
def scrape_dir_page(dir_url,driver):
    print ('-'*20,'Scraping directory page','-'*20)
    faculty_links = []
    faculty_base_url = 'https://cs.illinois.edu'
    #execute js on webpage to load faculty listings on webpage and get ready to parse the loaded HTML 
    soup = get_js_soup(dir_url,driver)     
    for link_holder in soup.find_all('div',class_='name'): #get list of all <div> of class 'name'
        rel_link = link_holder.find('a')['href'] #get url
        #url returned is relative, so we need to add base url
        faculty_links.append(faculty_base_url+rel_link) 
    print ('-'*20,'Found {} faculty profile urls'.format(len(faculty_links)),'-'*20)
    return faculty_links

# %% [markdown]
# It might take a few minutes to get all the urls

# %%
dir_url = 'https://cs.illinois.edu/about/people/all-faculty' #url of directory listings of CS faculty
faculty_links = scrape_dir_page(dir_url,driver)
# Out:
# -------------------- Scraping directory page --------------------
# -------------------- Found 189 faculty profile urls --------------------

# %% [markdown]
# Now let's scrape the faculty profile pages.
#
# The faculty homepages are listed under the "For more information" header. So, again let's try to find where this is placed in the HTML content.
#
# You'll notice the main profile is contained within the <section\> with class "directory-profile".
#
# There could multiple headers (<h\>) under this tab e.g. Education etc., we're looking for the one with text "For more information".
#
# There could be multiple listings (<li\>) under the header e.g. Research Group Page, etc. There is no specific way to identify the one corresponding to the homepage. But, if you look at a few profile pages, you'll notice a few patterns which are generally found in the anchor text accompanying the homepage url. e.g. presence of substrings like 'page' or 'site' are good indicators as long as other words like 'group' or 'course' are not present.
#
# Ofcourse, there might still be a few cases where the patterns do not work. For such cases and for cases where the homepage url is actually not listed on the profile page, we will treat the profile page as the homepage.
#
#
# ![img2.png](attachment:img2.png)

# %%
def scrape_faculty_page(fac_url,driver):
    soup = get_js_soup(fac_url,driver)
    homepage_found = False
    bio_url = ''
    bio = ''
    profile_sec = soup.find('section',class_='directory-profile')
    if profile_sec is not None:
        all_headers = profile_sec.find_all('h2')
        faculty_last_name = all_headers[0].get_text().lower().split()[-1] #find faculty last name
        faculty_first_name = all_headers[0].get_text().lower().split()[0]
        homepage_txts = ['site','page',faculty_last_name,faculty_first_name]
        exceptions = ['course ','research','group','cs','mirror','google scholar']
        #find the homepage url and extract all text from it
        for hdr in all_headers:  #first find the required header
            if hdr.text.lower() == 'for more information':
                next_tag = hdr.find_next('li')
                #find <li> which has homepage url
                while next_tag is not None: 
                    cand = next_tag.find('a')
                    next_tag = next_tag.next_sibling  #sibling means element present at the same level
                    try:
                        cand['href']
                    except:
                        continue
                    cand_text = cand.string

                    if cand_text is not None and (any(hp_txt in cand_text.lower() for hp_txt in homepage_txts) and 
                        not any(e in cand_text.lower() for e in exceptions)): #compare text to predefined patterns
                        bio_url = cand['href'] 
                        homepage_found = True
                        #check if homepage url is valid
                        if not(is_valid_homepage(bio_url,fac_url)):
                            homepage_found = False
                        else:
                            try:
                                bio_soup = remove_script(get_js_soup(bio_url,driver)) 
                            except:
                                print ('Could not access {}'.format(bio_url))
                                homepage_found = False
                        break 
                if homepage_found:
                    #get all the text from homepage(bio)
                    bio = process_bio(bio_soup.get_text(separator=' ')) 


        if not homepage_found:
            bio_url = fac_url #treat faculty profile page as homepage
            bio = process_bio(profile_sec.get_text(separator=' '))

    return bio_url,bio

# %% [markdown]
# It takes a few minutes to scrape all the urls

# %%
#Scrape homepages of all urls
bio_urls, bios = [],[]
tot_urls = len(faculty_links)
for i,link in enumerate(faculty_links):
    print ('-'*20,'Scraping faculty url {}/{}'.format(i+1,tot_urls),'-'*20)
    bio_url,bio = scrape_faculty_page(link,driver)
    if bio.strip()!= '' and bio_url.strip()!='':
        bio_urls.append(bio_url.strip())
        bios.append(bio)
driver.close()
# Out:
# -------------------- Scraping faculty url 1/189 --------------------
# -------------------- Scraping faculty url 2/189 --------------------
# -------------------- Scraping faculty url 3/189 --------------------
# -------------------- Scraping faculty url 4/189 --------------------
# -------------------- Scraping faculty url 5/189 --------------------
# -------------------- Scraping faculty url 6/189 --------------------
# -------------------- Scraping faculty url 7/189 --------------------
# -------------------- Scraping faculty url 8/189 --------------------
# -------------------- Scraping faculty url 9/189 --------------------
# -------------------- Scraping faculty url 10/189 --------------------
# -------------------- Scraping faculty url 11/189 --------------------
# -------------------- Scraping faculty url 12/189 --------------------
# -------------------- Scraping faculty url 13/189 --------------------
# -------------------- Scraping faculty url 14/189 --------------------
# -------------------- Scraping faculty url 15/189 --------------------
# -------------------- Scraping faculty url 16/189 --------------------
# -------------------- Scraping faculty url 17/189 --------------------
# -------------------- Scraping faculty url 18/189 --------------------
# -------------------- Scraping faculty url 19/189 --------------------
# -------------------- Scraping faculty url 20/189 --------------------
# -------------------- Scraping faculty url 21/189 --------------------
# -------------------- Scraping faculty url 22/189 --------------------
# -------------------- Scraping faculty url 23/189 --------------------
# -------------------- Scraping faculty url 24/189 --------------------
# -------------------- Scraping faculty url 25/189 --------------------
# -------------------- Scraping faculty url 26/189 --------------------
# -------------------- Scraping faculty url 27/189 --------------------
# -------------------- Scraping faculty url 28/189 --------------------
# -------------------- Scraping faculty url 29/189 --------------------
# -------------------- Scraping faculty url 30/189 --------------------
# -------------------- Scraping faculty url 31/189 --------------------
# -------------------- Scraping faculty url 32/189 --------------------
# -------------------- Scraping faculty url 33/189 --------------------
# -------------------- Scraping faculty url 34/189 --------------------
# -------------------- Scraping faculty url 35/189 --------------------
# -------------------- Scraping faculty url 36/189 --------------------
# -------------------- Scraping faculty url 37/189 --------------------
# -------------------- Scraping faculty url 38/189 --------------------
# -------------------- Scraping faculty url 39/189 --------------------
# -------------------- Scraping faculty url 40/189 --------------------
# -------------------- Scraping faculty url 41/189 --------------------
# -------------------- Scraping faculty url 42/189 --------------------
# -------------------- Scraping faculty url 43/189 --------------------
# -------------------- Scraping faculty url 44/189 --------------------
# -------------------- Scraping faculty url 45/189 --------------------
# -------------------- Scraping faculty url 46/189 --------------------
# -------------------- Scraping faculty url 47/189 --------------------
# -------------------- Scraping faculty url 48/189 --------------------
# -------------------- Scraping faculty url 49/189 --------------------
# -------------------- Scraping faculty url 50/189 --------------------
# -------------------- Scraping faculty url 51/189 --------------------
# -------------------- Scraping faculty url 52/189 --------------------
# -------------------- Scraping faculty url 53/189 --------------------
# -------------------- Scraping faculty url 54/189 --------------------
# -------------------- Scraping faculty url 55/189 --------------------
# -------------------- Scraping faculty url 56/189 --------------------
# -------------------- Scraping faculty url 57/189 --------------------
# -------------------- Scraping faculty url 58/189 --------------------
# -------------------- Scraping faculty url 59/189 --------------------
# -------------------- Scraping faculty url 60/189 --------------------
# -------------------- Scraping faculty url 61/189 --------------------
# -------------------- Scraping faculty url 62/189 --------------------
# -------------------- Scraping faculty url 63/189 --------------------
# -------------------- Scraping faculty url 64/189 --------------------
# -------------------- Scraping faculty url 65/189 --------------------
# -------------------- Scraping faculty url 66/189 --------------------
# -------------------- Scraping faculty url 67/189 --------------------
# -------------------- Scraping faculty url 68/189 --------------------
# -------------------- Scraping faculty url 69/189 --------------------
# -------------------- Scraping faculty url 70/189 --------------------
# -------------------- Scraping faculty url 71/189 --------------------
# -------------------- Scraping faculty url 72/189 --------------------
# -------------------- Scraping faculty url 73/189 --------------------
# -------------------- Scraping faculty url 74/189 --------------------
# -------------------- Scraping faculty url 75/189 --------------------
# -------------------- Scraping faculty url 76/189 --------------------
# -------------------- Scraping faculty url 77/189 --------------------
# -------------------- Scraping faculty url 78/189 --------------------
# -------------------- Scraping faculty url 79/189 --------------------
# -------------------- Scraping faculty url 80/189 --------------------
# -------------------- Scraping faculty url 81/189 --------------------
# -------------------- Scraping faculty url 82/189 --------------------
# -------------------- Scraping faculty url 83/189 --------------------
# -------------------- Scraping faculty url 84/189 --------------------
# -------------------- Scraping faculty url 85/189 --------------------
# -------------------- Scraping faculty url 86/189 --------------------
# -------------------- Scraping faculty url 87/189 --------------------
# -------------------- Scraping faculty url 88/189 --------------------
# -------------------- Scraping faculty url 89/189 --------------------
# -------------------- Scraping faculty url 90/189 --------------------
# -------------------- Scraping faculty url 91/189 --------------------
# -------------------- Scraping faculty url 92/189 --------------------
# -------------------- Scraping faculty url 93/189 --------------------
# -------------------- Scraping faculty url 94/189 --------------------
# -------------------- Scraping faculty url 95/189 --------------------
# -------------------- Scraping faculty url 96/189 --------------------
# -------------------- Scraping faculty url 97/189 --------------------
# -------------------- Scraping faculty url 98/189 --------------------
# -------------------- Scraping faculty url 99/189 --------------------
# -------------------- Scraping faculty url 100/189 --------------------
# -------------------- Scraping faculty url 101/189 --------------------
# -------------------- Scraping faculty url 102/189 --------------------
# -------------------- Scraping faculty url 103/189 --------------------
# -------------------- Scraping faculty url 104/189 --------------------
# -------------------- Scraping faculty url 105/189 --------------------
# -------------------- Scraping faculty url 106/189 --------------------
# -------------------- Scraping faculty url 107/189 --------------------
# -------------------- Scraping faculty url 108/189 --------------------
# -------------------- Scraping faculty url 109/189 --------------------
# -------------------- Scraping faculty url 110/189 --------------------
# -------------------- Scraping faculty url 111/189 --------------------
# -------------------- Scraping faculty url 112/189 --------------------
# -------------------- Scraping faculty url 113/189 --------------------
# -------------------- Scraping faculty url 114/189 --------------------
# -------------------- Scraping faculty url 115/189 --------------------
# -------------------- Scraping faculty url 116/189 --------------------
# -------------------- Scraping faculty url 117/189 --------------------
# -------------------- Scraping faculty url 118/189 --------------------
# -------------------- Scraping faculty url 119/189 --------------------
# -------------------- Scraping faculty url 120/189 --------------------
# -------------------- Scraping faculty url 121/189 --------------------
# -------------------- Scraping faculty url 122/189 --------------------
# -------------------- Scraping faculty url 123/189 --------------------
# -------------------- Scraping faculty url 124/189 --------------------
# -------------------- Scraping faculty url 125/189 --------------------
# -------------------- Scraping faculty url 126/189 --------------------
# -------------------- Scraping faculty url 127/189 --------------------
# -------------------- Scraping faculty url 128/189 --------------------
# -------------------- Scraping faculty url 129/189 --------------------
# -------------------- Scraping faculty url 130/189 --------------------
# -------------------- Scraping faculty url 131/189 --------------------
# -------------------- Scraping faculty url 132/189 --------------------
# -------------------- Scraping faculty url 133/189 --------------------
# -------------------- Scraping faculty url 134/189 --------------------
# -------------------- Scraping faculty url 135/189 --------------------
# -------------------- Scraping faculty url 136/189 --------------------
# -------------------- Scraping faculty url 137/189 --------------------
# -------------------- Scraping faculty url 138/189 --------------------
# -------------------- Scraping faculty url 139/189 --------------------
# -------------------- Scraping faculty url 140/189 --------------------
# -------------------- Scraping faculty url 141/189 --------------------
# -------------------- Scraping faculty url 142/189 --------------------
# -------------------- Scraping faculty url 143/189 --------------------
# -------------------- Scraping faculty url 144/189 --------------------
# -------------------- Scraping faculty url 145/189 --------------------
# -------------------- Scraping faculty url 146/189 --------------------
# -------------------- Scraping faculty url 147/189 --------------------
# -------------------- Scraping faculty url 148/189 --------------------
# -------------------- Scraping faculty url 149/189 --------------------
# -------------------- Scraping faculty url 150/189 --------------------
# -------------------- Scraping faculty url 151/189 --------------------
# -------------------- Scraping faculty url 152/189 --------------------
# -------------------- Scraping faculty url 153/189 --------------------
# -------------------- Scraping faculty url 154/189 --------------------
# -------------------- Scraping faculty url 155/189 --------------------
# -------------------- Scraping faculty url 156/189 --------------------
# -------------------- Scraping faculty url 157/189 --------------------
# -------------------- Scraping faculty url 158/189 --------------------
# -------------------- Scraping faculty url 159/189 --------------------
# -------------------- Scraping faculty url 160/189 --------------------
# -------------------- Scraping faculty url 161/189 --------------------
# -------------------- Scraping faculty url 162/189 --------------------
# -------------------- Scraping faculty url 163/189 --------------------
# -------------------- Scraping faculty url 164/189 --------------------
# -------------------- Scraping faculty url 165/189 --------------------
# -------------------- Scraping faculty url 166/189 --------------------
# -------------------- Scraping faculty url 167/189 --------------------
# -------------------- Scraping faculty url 168/189 --------------------
# -------------------- Scraping faculty url 169/189 --------------------
# -------------------- Scraping faculty url 170/189 --------------------
# -------------------- Scraping faculty url 171/189 --------------------
# -------------------- Scraping faculty url 172/189 --------------------
# -------------------- Scraping faculty url 173/189 --------------------
# -------------------- Scraping faculty url 174/189 --------------------
# -------------------- Scraping faculty url 175/189 --------------------
# -------------------- Scraping faculty url 176/189 --------------------
# -------------------- Scraping faculty url 177/189 --------------------
# -------------------- Scraping faculty url 178/189 --------------------
# -------------------- Scraping faculty url 179/189 --------------------
# -------------------- Scraping faculty url 180/189 --------------------
# -------------------- Scraping faculty url 181/189 --------------------
# -------------------- Scraping faculty url 182/189 --------------------
# -------------------- Scraping faculty url 183/189 --------------------
# -------------------- Scraping faculty url 184/189 --------------------
# -------------------- Scraping faculty url 185/189 --------------------
# -------------------- Scraping faculty url 186/189 --------------------
# -------------------- Scraping faculty url 187/189 --------------------
# -------------------- Scraping faculty url 188/189 --------------------
# -------------------- Scraping faculty url 189/189 --------------------

# %% [markdown]
# Finally, write urls and extracted bio to txt files

# %%
def write_lst(lst,file_):
    with open(file_,'w') as f:
        for l in lst:
            f.write(l)
            f.write('\n')

# %%
bio_urls_file = 'bio_urls.txt'
bios_file = 'bios.txt'
write_lst(bio_urls,bio_urls_file)
write_lst(bios,bios_file)
